# %% [markdown]
# # **Импорты**

# %%
# Последовательная модель НС
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization

# Утилиты для to_categorical()
from tensorflow.keras import utils
from tensorflow.keras.callbacks import EarlyStopping

# Алгоритмы оптимизации для обучения модели
from tensorflow.keras.optimizers import Adam

# Библиотека для работы с массивами
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Разделение данных на выборки
from sklearn.model_selection import train_test_split

# Для загрузки датасета
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler

# Отрисовка изображений в ноутбуке, а не в консоли или файле
# %matplotlib inline

# %% [markdown]
# # **Загрузка данных**

# %%
x_data = load_wine()['data']              # Загрузка набора данных о винах
y_data = load_wine()['target']            # Загрузка классов вин

print('Размерность x_data -', x_data.shape)
print('Размерность y_data -', y_data.shape)
print()

# Вывод примера данных
print('Данные по первому вину:',x_data[0])
print('Класс вина:',y_data[0])
# Out:
# Размерность x_data - (178, 13)
# Размерность y_data - (178,)
#
# Данные по первому вину: [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# Класс вина: 0

# %% [markdown]
# # **Кодирование**

# %%
# Перевод в one hot encoding
y_data = utils.to_categorical(y_data, 3)

# Разбиение наборов на общую и тестовую выборки
x_all, x_test, y_all, y_test = train_test_split(x_data,
                                                y_data,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(x_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)

print(x_train.shape)
print(y_train.shape)
print()
print(x_val.shape)
print(y_val.shape)
# Out:
# (144, 13)
# (144, 3)
#
# (16, 13)
# (16, 3)

# %% [markdown]
# # **Нормализация данных**

# %%
# Стандартизация признаков (нормализация с вычитанием среднего и делением на стандартное отклонение)
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # **Создание модели нейронной сети**

# %%
# Создание последовательной модели
model = Sequential([
    Dense(64, input_shape=(13,), activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # **Компиляция и просмотр архитектуры**

# %%
# Компиляция модели
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Вывод структуры и количества параметров
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,811 (14.89 KB)
#  Trainable params: 3,683 (14.39 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# # **Обучение с ранней остановкой**

# %%
# Ранняя остановка, чтобы избежать переобучения
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Обучение
history = model.fit(
    x_train_scaled, y_train,
    validation_data=(x_val_scaled, y_val),
    epochs=200,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.4097 - loss: 1.1148 - val_accuracy: 0.3750 - val_loss: 1.1535
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4583 - loss: 1.0765 - val_accuracy: 0.5000 - val_loss: 1.0711
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5694 - loss: 0.9027 - val_accuracy: 0.6250 - val_loss: 1.0069
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5694 - loss: 0.8559 - val_accuracy: 0.6250 - val_loss: 0.9411
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6458 - loss: 0.7207 - val_accuracy: 0.6875 - val_loss: 0.8863
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7500 - loss: 0.6658 - val_accuracy: 0.8125 - val_loss: 0.8304
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7778 - loss: 0.5640 - val_accuracy: 0.8125 - val_loss: 0.7729
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8403 - loss: 0.5137 - val_accuracy: 0.8750 - val_loss: 0.7130
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8750 - loss: 0.4229 - val_accuracy: 0.8750 - val_loss: 0.6518
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9097 - loss: 0.3810 - val_accuracy: 0.8750 - val_loss: 0.5915
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9028 - loss: 0.3585 - val_accuracy: 0.9375 - val_loss: 0.5206
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9583 - loss: 0.2258 - val_accuracy: 0.9375 - val_loss: 0.4548
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9167 - loss: 0.3050 - val_accuracy: 0.8750 - val_loss: 0.3953
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9583 - loss: 0.2202 - val_accuracy: 0.8750 - val_loss: 0.3464
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9375 - loss: 0.2002 - val_accuracy: 0.8750 - val_loss: 0.3122
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9653 - loss: 0.1590 - val_accuracy: 0.8750 - val_loss: 0.2844
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9653 - loss: 0.1378 - val_accuracy: 0.8750 - val_loss: 0.2658
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9514 - loss: 0.1329 - val_accuracy: 0.8750 - val_loss: 0.2529
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9583 - loss: 0.1413 - val_accuracy: 0.8750 - val_loss: 0.2400
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 0.1008 - val_accuracy: 0.8750 - val_loss: 0.2219
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9722 - loss: 0.1023 - val_accuracy: 0.8750 - val_loss: 0.2078
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9583 - loss: 0.1254 - val_accuracy: 0.8750 - val_loss: 0.1882
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0727 - val_accuracy: 0.8750 - val_loss: 0.1738
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0800 - val_accuracy: 0.8750 - val_loss: 0.1595
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9722 - loss: 0.0855 - val_accuracy: 0.9375 - val_loss: 0.1470
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 0.0784 - val_accuracy: 0.9375 - val_loss: 0.1346
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0660 - val_accuracy: 0.9375 - val_loss: 0.1296
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9653 - loss: 0.0822 - val_accuracy: 0.9375 - val_loss: 0.1251
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0567 - val_accuracy: 0.9375 - val_loss: 0.1302
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0460 - val_accuracy: 0.9375 - val_loss: 0.1370
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9653 - loss: 0.0798 - val_accuracy: 0.8750 - val_loss: 0.1480
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9792 - loss: 0.0599 - val_accuracy: 0.8750 - val_loss: 0.1472
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0446 - val_accuracy: 0.8750 - val_loss: 0.1509
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9792 - loss: 0.0842 - val_accuracy: 0.8750 - val_loss: 0.1585
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9792 - loss: 0.0545 - val_accuracy: 0.8750 - val_loss: 0.1528
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9722 - loss: 0.0709 - val_accuracy: 0.9375 - val_loss: 0.1172
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 0.0433 - val_accuracy: 0.9375 - val_loss: 0.1164
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9653 - loss: 0.1143 - val_accuracy: 0.9375 - val_loss: 0.1495
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9792 - loss: 0.0403 - val_accuracy: 0.9375 - val_loss: 0.1260
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0451 - val_accuracy: 0.9375 - val_loss: 0.1244
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9722 - loss: 0.0611 - val_accuracy: 0.9375 - val_loss: 0.1202
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0367 - val_accuracy: 0.9375 - val_loss: 0.1230
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9653 - loss: 0.0806 - val_accuracy: 0.9375 - val_loss: 0.1349
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9861 - loss: 0.0616 - val_accuracy: 0.9375 - val_loss: 0.1252
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9931 - loss: 0.0328 - val_accuracy: 0.9375 - val_loss: 0.1237
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9861 - loss: 0.0333 - val_accuracy: 0.9375 - val_loss: 0.1240
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9931 - loss: 0.0225 - val_accuracy: 0.9375 - val_loss: 0.1234
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9861 - loss: 0.0457 - val_accuracy: 0.9375 - val_loss: 0.1206
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9792 - loss: 0.0641 - val_accuracy: 0.9375 - val_loss: 0.1171
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9861 - loss: 0.0394 - val_accuracy: 0.9375 - val_loss: 0.1148
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9375 - val_loss: 0.1211
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9861 - loss: 0.0224 - val_accuracy: 0.9375 - val_loss: 0.1279
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9792 - loss: 0.0407 - val_accuracy: 0.9375 - val_loss: 0.1168
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.9375 - val_loss: 0.1068
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9931 - loss: 0.0169 - val_accuracy: 0.9375 - val_loss: 0.1006
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9931 - loss: 0.0327 - val_accuracy: 0.9375 - val_loss: 0.1008
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 0.9375 - val_loss: 0.0992
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9792 - loss: 0.0506 - val_accuracy: 0.9375 - val_loss: 0.0911
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9861 - loss: 0.0469 - val_accuracy: 0.9375 - val_loss: 0.0871
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9861 - loss: 0.0291 - val_accuracy: 0.9375 - val_loss: 0.1299
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9931 - loss: 0.0294 - val_accuracy: 0.8750 - val_loss: 0.1670
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9931 - loss: 0.0226 - val_accuracy: 0.8750 - val_loss: 0.1803
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9861 - loss: 0.0483 - val_accuracy: 0.8750 - val_loss: 0.1913
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9931 - loss: 0.0212 - val_accuracy: 0.8750 - val_loss: 0.1953
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0145 - val_accuracy: 0.8750 - val_loss: 0.2036
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9861 - loss: 0.0456 - val_accuracy: 0.8750 - val_loss: 0.2118
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9792 - loss: 0.0494 - val_accuracy: 0.8750 - val_loss: 0.2052
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9792 - loss: 0.0508 - val_accuracy: 0.8750 - val_loss: 0.1912
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.8750 - val_loss: 0.1988
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8750 - val_loss: 0.2022
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9931 - loss: 0.0211 - val_accuracy: 0.8750 - val_loss: 0.2326
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9861 - loss: 0.0392 - val_accuracy: 0.8750 - val_loss: 0.2480
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9931 - loss: 0.0231 - val_accuracy: 0.8750 - val_loss: 0.2388
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9931 - loss: 0.0187 - val_accuracy: 0.8750 - val_loss: 0.2102
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9861 - loss: 0.0246 - val_accuracy: 0.8750 - val_loss: 0.2015
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9931 - loss: 0.0122 - val_accuracy: 0.8750 - val_loss: 0.1889
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9931 - loss: 0.0122 - val_accuracy: 0.8750 - val_loss: 0.1775
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.9375 - val_loss: 0.1585
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.9375 - val_loss: 0.1422

# %% [markdown]
# # **Оценка на тестовой выборке и график обучения**

# %%
# Оценка на тестовой выборке
test_loss, test_acc = model.evaluate(x_test_scaled, y_test, verbose=0)
print(f'Точность на тестовой выборке: {test_acc:.4f}')

# Построение графиков потерь и точности
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Потери')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Точность')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Точность на тестовой выборке: 1.0000
